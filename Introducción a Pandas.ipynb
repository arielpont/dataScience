# %%
# Es lo más parecido en Python al Microsoft Excel

# importarlo siempre como "pd"
import pandas as pd

# %%
# df = dataframe
# creamos un objeto con la información del documento
df = pd.read_csv("csv/Sample10K.csv", nrows = 1000)

# %%
# muestra los datos
# siempre la primer fila la muestra con el valor 0

df.head(10)
# Out:
#    Serial Number                         Company Name  Employee Markme  \
# 0  9788189999599                       TALES OF SHIVA             Mark
# 1  9780099578079            1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                             MY KUMAN             Mark
# 3  9780007880331              THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455                     THE BLACK CIRCLE             Mark
# 5  9788126525072        THE THREE LAWS OF PERFORMANCE             Mark
# 6  9789381626610                    CHAMarkKYA MANTRA             Mark
# 7  9788184513523                             59.FLAGS             Mark
# 8  9780743234801  THE POWER OF POSITIVE THINKING FROM             Mark
# 9  9789381529621           YOU CAN IF YO THINK YO CAN            PEALE
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# ...

# %%
# muestra las últimas 5 filas
df.tail()
# Out:
#      Serial Number                     Company Name Employee Markme  \
# 995  9781862305274  BOY IN THE STRIPED PYJAMAS  THE     Boyne  John
# 996  9781730155116             SHRI KRISHMark LEELA            Mark
# 997  9789350891896               MENTAL MATHEMATICS            Mark
# 998  9789383182008           MATHEMATICS CLASS 10th     R.D. SHARMA
# 999  9789383182084           MICROECONOMICS CLASS12    SANDEEP GARG
#
#          Description  Leave
# 995      Definitions      0
# 996       DEREAMLAND      0
# 997       DEREAMLAND      0
# 998  DHANPAT RAI &CO      5
# 999  DHANPAT RAI &CO      1

# %%
# reordenar la base de datos, solo la muestra
# frac = 1 hace que mantenga el 100% las filas que tenemos
df.sample(frac = 1)

# ahora hacemos que la guarde remezclado
df = df.sample(frac = 1)
# Out:
#      Serial Number                       Company Name  \
# 41   9789383454730                    WORLD GEOGRAPHY
# 624  9789386360403                    THE JUNGLE BOOK
# 449  9781526603326                          THE EXILE
# 208  9789383064090              THE PARROTS OF DESIRE
# 186  9789382277149             KORMA KHEER AND KISMET
# ..             ...                                ...
# 189  9789383064274                   THE TALENT SUTRA
# 978  9780552166188                        THE AWARD .
# 37   9789383454570  GENERAL STUDIES PAPER - II (2016)
# 32   9789383454204  THE CONSTITUTION OF INDIA 2ND / E
# 482  9781472520876               THE SECOND WORLD WAR
#
#                     Employee Markme                      Description  Leave
# 41                       DR KHULLAR  ACCESS PUBLISHING INDIA PVT.LTD      5
# 624                            Mark                BPI INDIA PVT LTD      0
# 449  CATHY SCOTTCLARK & ADRIAN LEVY                      BLOOMS BURY      0
# ...

# %%
# nos muestra las columnas
df.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
# nos muestra los tipos de datos
df.dtypes
# Out:
# Serial Number       int64
# Company Name       object
# Employee Markme    object
# Description        object
# Leave               int64
# dtype: object

# %%
# nos muestra los valores en un formato poco amigable pero rápido
# devuelve un ARRAY que nos va a permitir trabajar como matriz
df.values
# Out:
# array([[9788189999599, 'TALES OF SHIVA', 'Mark', 'mark', 0],
#        [9780099578079, '1Q84 THE COMPLETE TRILOGY', 'HARUKI MURAKAMI',
#         'Mark', 0],
#        [9780198082897, 'MY KUMAN', 'Mark', 'Mark', 0],
#        ...,
#        [9789350891896, 'MENTAL MATHEMATICS', 'Mark', 'DEREAMLAND', 0],
#        [9789383182008, 'MATHEMATICS CLASS 10th', 'R.D. SHARMA',
#         'DHANPAT RAI &CO', 5],
#        [9789383182084, 'MICROECONOMICS CLASS12', 'SANDEEP GARG',
#         'DHANPAT RAI &CO', 1]], dtype=object)

# %%
# podemos crear otro dataframe que solo tenga algunas filas que nos interesen del archivo
df2 = df.head(10)

# %%
# solo muestra 10 y no 20 porque guardamos esa cantidad antes
df2.head(20)
# Out:
#    Serial Number                         Company Name  Employee Markme  \
# 0  9788189999599                       TALES OF SHIVA             Mark
# 1  9780099578079            1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                             MY KUMAN             Mark
# 3  9780007880331              THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455                     THE BLACK CIRCLE             Mark
# 5  9788126525072        THE THREE LAWS OF PERFORMANCE             Mark
# 6  9789381626610                    CHAMarkKYA MANTRA             Mark
# 7  9788184513523                             59.FLAGS             Mark
# 8  9780743234801  THE POWER OF POSITIVE THINKING FROM             Mark
# 9  9789381529621           YOU CAN IF YO THINK YO CAN            PEALE
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# ...
