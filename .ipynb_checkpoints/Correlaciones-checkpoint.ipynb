# %%
import pandas as pd
import numpy as np
df = pd.read_csv("csv/flights.csv")

# %%
np.corrcoef(df["LATE_AIRCRAFT_DELAY"],df["AIRLINE_DELAY"])
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
df.corr()
# Out:
#                      YEAR  MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN    NaN       NaN          NaN            NaN
# MONTH                 NaN    NaN       NaN          NaN            NaN
# DAY                   NaN    NaN  1.000000     1.000000       0.049269
# DAY_OF_WEEK           NaN    NaN  1.000000     1.000000       0.049269
# FLIGHT_NUMBER         NaN    NaN  0.049269     0.049269       1.000000
# SCHEDULED_DEPARTURE   NaN    NaN -0.321034    -0.321034      -0.004108
# DEPARTURE_TIME        NaN    NaN -0.312793    -0.312793      -0.000146
# DEPARTURE_DELAY       NaN    NaN  0.004560     0.004560       0.009351
# TAXI_OUT              NaN    NaN  0.039736     0.039736       0.081421
# WHEELS_OFF            NaN    NaN -0.304484    -0.304484       0.006628
# SCHEDULED_TIME        NaN    NaN -0.018421    -0.018421      -0.341910
# ELAPSED_TIME          NaN    NaN -0.015861    -0.015861      -0.326888
# ...

# %%
# permite ver las variables que se correlaciones fuertemente de una manera fácil
corr = round(df.corr(),3)
corr.style.background_gradient()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\User\anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_f81b6e7a_d90a_11ea_a6c4_24ee9ab12776row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f81b6e7a_d90a_11ea_a6c4_24ee9ab12776row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f81b6e7a_d90a_11ea_a6c4_24ee9ab12776row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f81b6e7a_d90a_11ea_a6c4_24ee9ab12776row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...
